# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/df_final_full.csv')

# %% [markdown]
# ### Qual a quantidade total de livros da base?

# %%
df['book_id'].nunique()
# Out:
# 20216

# %% [markdown]
# ### Qual a quantidade de livros que possuí apenas 1 autor?

# %%
books = df.groupby(['book_id'])

result = books['author_name'].nunique() == 1
result.value_counts()

# Contagem de "True" sao os livros que possuem apenas 1 autor
# Out:
# True     14753
# False     5463
# Name: author_name, dtype: int64

# %% [markdown]
# ### Quais os 5 autores com a maior quantidade de livros?

# %%
df.groupby('author_name')['book_id'].nunique().sort_values(ascending = False).head(5)
## A coluna book_id se repete, por isso o uso da função nunique(), que conta valores distintos da mesma.
# Out:
# author_name
# Weezag                 258
# Rand McNally           212
# William Shakespeare    117
# Matthew Preston         83
# Kevin Lee               83
# Name: book_id, dtype: int64

# %%
len(df.loc[df['author_name'] == 'Weezag'].groupby('book_id').nunique()) ## conferindo
# Out:
# 258

# %% [markdown]
# ### Qual a quantidade de livros por categoria?

# %%
category = df.groupby(['category_name'])
category['book_id'].nunique().to_csv('qtd_livros_categoria.csv')
category['book_id'].nunique()
# Out:
# category_name
# 20th Century & Contemporary Classical Music     2
# 20th Century History: C 1900  To C 2000        92
# 21st Century History: From C 2000 -            19
# ABC                                             2
# Abnormal Psychology                            17
#                                                ..
# Zoology & Animal Sciences                      50
# Zoology: Invertebrates                          3
# Zoology: Mammals                                8
# Zoos & Wildlife Parks                           1
# Zoroastrianism                                  3
# Name: book_id, Length: 1731, dtype: int64

# %% [markdown]
# ### Quais as 5 categorias com a maior quantidade de livros?

# %%
category = df.groupby(['category_name'])
category['book_id'].nunique().sort_values(ascending = False).head(5)
# Out:
# category_name
# Television                      2225
# Teaching Skills & Techniques    2061
# World Atlases / World Maps      1896
# Usage & Grammar Guides          1862
# Theatre Studies                 1854
# Name: book_id, dtype: int64

# %% [markdown]
# ### Qual o formato com a maior quantidade de livros?

# %%
formats = df.groupby(['format_name'])
formats['book_id'].nunique().sort_values(ascending = False).head(5)
# Out:
# format_name
# Paperback    13497
# Hardback      4955
# Book           463
# Calendar       303
# CD             227
# Name: book_id, dtype: int64

# %% [markdown]
# ### Considerando a coluna “bestsellers-rank”, quais os 10 livros mais bem posicionados?

# %%
df.groupby(['title', 'bestsellers-rank']).count().sort_values(by = 'bestsellers-rank', ascending = False).head(10)
# Out:
#                                                                      Unnamed: 0  \
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0                 10
# On Latin Adverbs                                   3579654.0                  5
# Feeling Asian Modernities - Transnational Consu... 3569736.0                  6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0                 12
# The Real (Arab) World: v. 2                        3567310.0                  5
# Multi-verb Constructions : A View from the Amer... 3565119.0                 12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0                  2
# Ghost Journal                                      3555958.0                  4
# Handbook of Generative Approaches to Language A... 3546984.0                 10
# Ghost Stories of Arizona and New Mexico            3546676.0                  3
#
#                                                                      book_id  \
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0              10
# On Latin Adverbs                                   3579654.0               5
# Feeling Asian Modernities - Transnational Consu... 3569736.0               6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0              12
# The Real (Arab) World: v. 2                        3567310.0               5
# Multi-verb Constructions : A View from the Amer... 3565119.0              12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0               2
# Ghost Journal                                      3555958.0               4
# Handbook of Generative Approaches to Language A... 3546984.0              10
# Ghost Stories of Arizona and New Mexico            3546676.0               3
#
#                                                                      category_name  \
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0                    10
# On Latin Adverbs                                   3579654.0                     5
# Feeling Asian Modernities - Transnational Consu... 3569736.0                     6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0                    12
# The Real (Arab) World: v. 2                        3567310.0                     5
# Multi-verb Constructions : A View from the Amer... 3565119.0                    12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0                     2
# Ghost Journal                                      3555958.0                     4
# Handbook of Generative Approaches to Language A... 3546984.0                    10
# Ghost Stories of Arizona and New Mexico            3546676.0                     3
#
#                                                                      author_name  \
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0                  10
# On Latin Adverbs                                   3579654.0                   5
# Feeling Asian Modernities - Transnational Consu... 3569736.0                   6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0                  12
# The Real (Arab) World: v. 2                        3567310.0                   5
# Multi-verb Constructions : A View from the Amer... 3565119.0                  12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0                   2
# Ghost Journal                                      3555958.0                   4
# Handbook of Generative Approaches to Language A... 3546984.0                  10
# Ghost Stories of Arizona and New Mexico            3546676.0                   3
#
#                                                                      format_name  \
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0                  10
# On Latin Adverbs                                   3579654.0                   5
# Feeling Asian Modernities - Transnational Consu... 3569736.0                   6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0                  12
# The Real (Arab) World: v. 2                        3567310.0                   5
# Multi-verb Constructions : A View from the Amer... 3565119.0                  12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0                   2
# Ghost Journal                                      3555958.0                   4
# Handbook of Generative Approaches to Language A... 3546984.0                  10
# Ghost Stories of Arizona and New Mexico            3546676.0                   3
#
#                                                                      rating-avg  \
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0                 10
# On Latin Adverbs                                   3579654.0                  5
# Feeling Asian Modernities - Transnational Consu... 3569736.0                  6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0                 12
# The Real (Arab) World: v. 2                        3567310.0                  5
# Multi-verb Constructions : A View from the Amer... 3565119.0                 12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0                  2
# Ghost Journal                                      3555958.0                  4
# Handbook of Generative Approaches to Language A... 3546984.0                 10
# Ghost Stories of Arizona and New Mexico            3546676.0                  3
#
#                                                                      publication-date
# title                                              bestsellers-rank
# After the Break : Television Theory Today          3586486.0                       10
# On Latin Adverbs                                   3579654.0                        5
# Feeling Asian Modernities - Transnational Consu... 3569736.0                        6
# Lexikon der alteren germanischen Lehnwoerter in... 3567995.0                       12
# The Real (Arab) World: v. 2                        3567310.0                        5
# Multi-verb Constructions : A View from the Amer... 3565119.0                       12
# The Noun Phrase in Ancient Greek : A Functional... 3564946.0                        2
# Ghost Journal                                      3555958.0                        4
# Handbook of Generative Approaches to Language A... 3546984.0                       10
# Ghost Stories of Arizona and New Mexico            3546676.0                        3

# %% [markdown]
# ### Considerando a coluna “rating-avg”, quais os 10 livros mais bem posicionados?

# %%
df.groupby(['title', 'rating-avg']).count().sort_values(by = 'rating-avg', ascending = False).head(10)
# Out:
#                                                                Unnamed: 0  \
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0                  3
# The Learning and Teaching of Reading and Writing   5.0                 18
# Ask the Psychic Medium                             5.0                  5
# Collective Consciousness : How to Transcend Mas... 5.0                  4
# Self-Regulation in Education                       5.0                 13
# Improvised Explosives & Munitions                  5.0                  1
# Selected Writings : On Self-Organization, Philo... 5.0                 15
# Asia Classic, Tubed : Wall Maps Continents         5.0                  6
# Practicing Music by Design : Historic Virtuosi ... 5.0                  9
# A Reading Book of the Turkish Language, with a ... 5.0                  2
#
#                                                                book_id  \
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0               3
# The Learning and Teaching of Reading and Writing   5.0              18
# Ask the Psychic Medium                             5.0               5
# Collective Consciousness : How to Transcend Mas... 5.0               4
# Self-Regulation in Education                       5.0              13
# Improvised Explosives & Munitions                  5.0               1
# Selected Writings : On Self-Organization, Philo... 5.0              15
# Asia Classic, Tubed : Wall Maps Continents         5.0               6
# Practicing Music by Design : Historic Virtuosi ... 5.0               9
# A Reading Book of the Turkish Language, with a ... 5.0               2
#
#                                                                category_name  \
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0                     3
# The Learning and Teaching of Reading and Writing   5.0                    18
# Ask the Psychic Medium                             5.0                     5
# Collective Consciousness : How to Transcend Mas... 5.0                     4
# Self-Regulation in Education                       5.0                    13
# Improvised Explosives & Munitions                  5.0                     1
# Selected Writings : On Self-Organization, Philo... 5.0                    15
# Asia Classic, Tubed : Wall Maps Continents         5.0                     6
# Practicing Music by Design : Historic Virtuosi ... 5.0                     9
# A Reading Book of the Turkish Language, with a ... 5.0                     2
#
#                                                                author_name  \
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0                   3
# The Learning and Teaching of Reading and Writing   5.0                  18
# Ask the Psychic Medium                             5.0                   5
# Collective Consciousness : How to Transcend Mas... 5.0                   4
# Self-Regulation in Education                       5.0                  13
# Improvised Explosives & Munitions                  5.0                   1
# Selected Writings : On Self-Organization, Philo... 5.0                  15
# Asia Classic, Tubed : Wall Maps Continents         5.0                   6
# Practicing Music by Design : Historic Virtuosi ... 5.0                   9
# A Reading Book of the Turkish Language, with a ... 5.0                   2
#
#                                                                format_name  \
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0                   3
# The Learning and Teaching of Reading and Writing   5.0                  18
# Ask the Psychic Medium                             5.0                   5
# Collective Consciousness : How to Transcend Mas... 5.0                   4
# Self-Regulation in Education                       5.0                  13
# Improvised Explosives & Munitions                  5.0                   1
# Selected Writings : On Self-Organization, Philo... 5.0                  15
# Asia Classic, Tubed : Wall Maps Continents         5.0                   6
# Practicing Music by Design : Historic Virtuosi ... 5.0                   9
# A Reading Book of the Turkish Language, with a ... 5.0                   2
#
#                                                                bestsellers-rank  \
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0                        3
# The Learning and Teaching of Reading and Writing   5.0                       18
# Ask the Psychic Medium                             5.0                        5
# Collective Consciousness : How to Transcend Mas... 5.0                        4
# Self-Regulation in Education                       5.0                       13
# Improvised Explosives & Munitions                  5.0                        1
# Selected Writings : On Self-Organization, Philo... 5.0                       15
# Asia Classic, Tubed : Wall Maps Continents         5.0                        6
# Practicing Music by Design : Historic Virtuosi ... 5.0                        9
# A Reading Book of the Turkish Language, with a ... 5.0                        2
#
#                                                                publication-date
# title                                              rating-avg
# The Early Shows : A Reference Guide to Network ... 5.0                        3
# The Learning and Teaching of Reading and Writing   5.0                       18
# Ask the Psychic Medium                             5.0                        5
# Collective Consciousness : How to Transcend Mas... 5.0                        4
# Self-Regulation in Education                       5.0                       13
# Improvised Explosives & Munitions                  5.0                        1
# Selected Writings : On Self-Organization, Philo... 5.0                       15
# Asia Classic, Tubed : Wall Maps Continents         5.0                        6
# Practicing Music by Design : Historic Virtuosi ... 5.0                        9
# A Reading Book of the Turkish Language, with a ... 5.0                        2

# %% [markdown]
# ### Quantos livros possuem “rating-avg” maior do que 3,5?

# %%
len(df['book_id'].loc[df['rating-avg']  > 3.5].unique())
# Out:
# 8182

# %% [markdown]
# ### Quantos livros tem data de publicação (publication-date) maior do que 01-01-2020?

# %%
df.head(10)
# Out:
#    Unnamed: 0  book_id                                              title  \
# 0           0        0                                                 We
# 1           1        0                                                 We
# 2           2      365                                     What Haunts Us
# 3           3      462                                      Alpine Skiing
# 4           4      590                                       Snowboarding
# 5           5      590                                       Snowboarding
# 6           6      615                            Doctor Who: Plague City
# 7           7      865  Una Nueva Entrega : Charla Sencilla Para Tiemp...
# 8           8      947                                         El Sanador
# 9           9      965                                    Precious Little
#
#           category_name           author_name format_name  bestsellers-rank  \
# 0  Contemporary Fiction      Yevgeny Zamyatin   Paperback            2038.0
# 1  Contemporary Fiction        Clarence Brown   Paperback            2038.0
# 2  Contemporary Fiction           Loren Niemi   Paperback               0.0
# 3  Contemporary Fiction          John Yacenda   Paperback               0.0
# 4  Contemporary Fiction  Anna Marie Bruechert   Paperback               0.0
# 5  Contemporary Fiction       Rob Reichenfeld   Paperback               0.0
# 6  Contemporary Fiction       Jonathan Morris   Paperback               0.0
# 7  Contemporary Fiction           Lee Carroll   Paperback               0.0
# 8  Contemporary Fiction          John Diamond   Paperback               0.0
# 9  Contemporary Fiction      Madeleine George   Paperback         1762612.0
#
#    rating-avg     publication-date
# 0        3.91  1993-11-25 00:00:00
# 1        3.91  1993-11-25 00:00:00
# 2        4.50  2019-02-12 00:00:00
# 3        0.00  1992-02-01 00:00:00
# 4        3.00  1994-12-01 00:00:00
# 5        3.00  1994-12-01 00:00:00
# 6        3.89  2020-12-17 00:00:00
# 7        4.50  2010-04-19 00:00:00
# 8        0.00  2003-07-01 00:00:00
# 9        3.83  2013-02-06 00:00:00

# %%
df['publication-date'] = pd.to_datetime(df['publication-date'], errors='coerce')

# %%
df['book_id'].loc[df['publication-date']  > '01-01-2020'].nunique()
# Out:
# 1172
